# %%
import pandas as pd

# %% [markdown]
# Below data has semicolon seperatedvalues,some invalid values like last few 100 rows
# of column1 has ;;;;;;;;;; so,
# #### We need to use skipfooter: Skipfooter skips rows from the bottom of the DataFrame.It counts from bottom

# %%
AirQuality = pd.read_csv("E:/Dataset/Data/AirQuality.csv",sep=";",skipfooter=114)
AirQuality
# Out:
# C:\Users\kashp\AppData\Local\Temp/ipykernel_18272/1683075669.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   AirQuality = pd.read_csv("E:/Dataset/Data/AirQuality.csv",sep=";",skipfooter=114)
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6         1360       150     11,9
# 1     10/03/2004  19.00.00      2         1292       112      9,4
# 2     10/03/2004  20.00.00    2,2         1402        88      9,0
# 3     10/03/2004  21.00.00    2,2         1376        80      9,2
# 4     10/03/2004  22.00.00    1,6         1272        51      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1         1314      -200     13,5
# 9353  04/04/2005  11.00.00    2,4         1163      -200     11,4
# 9354  04/04/2005  12.00.00    2,4         1142      -200     12,4
# ...

# %%
AirQuality
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6         1360       150     11,9
# 1     10/03/2004  19.00.00      2         1292       112      9,4
# 2     10/03/2004  20.00.00    2,2         1402        88      9,0
# 3     10/03/2004  21.00.00    2,2         1376        80      9,2
# 4     10/03/2004  22.00.00    1,6         1272        51      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1         1314      -200     13,5
# 9353  04/04/2005  11.00.00    2,4         1163      -200     11,4
# 9354  04/04/2005  12.00.00    2,4         1142      -200     12,4
# 9355  04/04/2005  13.00.00    2,1         1003      -200      9,5
# 9356  04/04/2005  14.00.00    2,2         1071      -200     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %% [markdown]
# ### nrows : No of rows we need to read after taking the header
# Below we can first use nrows then,skiprows and header

# %%
Messy = pd.read_csv("E:/Dataset/Data/messydata.csv",sep=' ',header=3,nrows=3,skiprows=[4,7,10])
Messy
# Out:
#      name     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug  \
# 0     IBM  156.08  160.01  159.81  165.22  172.25  167.15  164.75  152.77
# 1    MSFT   45.51   43.08   42.13   43.47   47.53   45.96   45.61   45.51
# 2  GOOGLE  512.42  537.99  559.72  540.50  535.24  532.92  590.09  636.84
#
#       Sep     Oct     Nov     Dec
# 0  145.36  146.11  137.21  137.96
# 1   43.56   48.70   53.88   55.40
# 2  617.93  663.59  735.39  755.35

# %% [markdown]
# If we want to read the data excluding the header then we can use nrows

# %%
cars = pd.read_csv("E:/Dataset/Data/usedcars.csv",nrows=10)
cars
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO
# 5  2010   SEL  17495    25125  Silver         AUTO
# 6  2011   SEL  17000    27393    Blue         AUTO
# 7  2010   SEL  16995    21026  Silver         AUTO
# 8  2011   SES  16995    32655  Silver         AUTO
# 9  2010   SES  16995    36116  Silver         AUTO

# %% [markdown]
# #### Below instead of skipfooter we can use nrows to display the number of rows which we need

# %%
AirQuality = pd.read_csv("E:/Dataset/Data/AirQuality.csv",sep=";",nrows=9357)
AirQuality.shape
# Out:
# (9357, 17)

# %% [markdown]
# ### usecols : usecols is supposed to provide a filter before reading the whole DataFrame into memory. If used properly, there should never be a need to delete columns after reading.

# %%
cars = pd.read_csv("E:/Dataset/Data/usedcars.csv",
                   usecols=['model','price','mileage'])
cars
# Out:
#     model  price  mileage
# 0     SEL  21992     7413
# 1     SEL  20995    10926
# 2     SEL  19995     7351
# 3     SEL  17809    11613
# 4      SE  17500     8367
# ..    ...    ...      ...
# 145   SES   6200    95000
# 146    SE   5995    87003
# 147    SE   5980    96841
# 148    SE   4899   151479
# 149    SE   3800   109259
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Converters : Converters allows you to parse your input data to convert it to a desired dtype using a conversion function

# %% [markdown]
# #### Below first we need to assign the header, rename the columns also we see there is a column speices which has three values 0,1,2we need to assign the values as 0 = Setosa,1=Verginica,2=Versicolor

# %% [markdown]
# #### We need to create a function for assigning the valuesbefore reading the data

# %%
def  convert_species(x):
    if int(x)==0:
        return 'setosa'
    elif int(x)==1:
        return 'verginica'
    else:
        return 'versicolor'

# %% [markdown]
# #### Applying the perticular function
# #### Below we are first renaming the column names and then using the function
# #### and in the function we need to use the name of the column which is renamed only

# %%
iris = pd.read_csv("E:Dataset/Data/iris.csv",header=0,
                   names=['sepal_length','sepal_width','petal_length','petal_width','species'],
                  converters={"species":convert_species})
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# ..            ...          ...           ...          ...         ...
# 145           6.7          3.0           5.2          2.3  versicolor
# 146           6.3          2.5           5.0          1.9  versicolor
# 147           6.5          3.0           5.2          2.0  versicolor
# 148           6.2          3.4           5.4          2.3  versicolor
# 149           5.9          3.0           5.1          1.8  versicolor
#
# [150 rows x 5 columns]

# %% [markdown]
# ####  Below we see in model column there are three distinct values SEL,SES and SE
# #### So we need to assign common value to SE and SES and another value to SEL
# #### There is an alternate method for "if else" method for creating a function, we can use lambda function aswell
# #### Lambda function needs not to be created before reading the data but it can be created while reading the data

# %%
cars = pd.read_csv("E:/Dataset/Data/usedcars.csv",
                  converters={'model':lambda x:
                              'Normal' if x in ('SE','SES')
                             else 'Luxary'})
cars
# Out:
#      year   model  price  mileage   color transmission
# 0    2011  Luxary  21992     7413  Yellow         AUTO
# 1    2011  Luxary  20995    10926    Gray         AUTO
# 2    2011  Luxary  19995     7351  Silver         AUTO
# 3    2011  Luxary  17809    11613    Gray         AUTO
# 4    2012  Normal  17500     8367   White         AUTO
# ..    ...     ...    ...      ...     ...          ...
# 145  2006  Normal   6200    95000  Silver         AUTO
# 146  2002  Normal   5995    87003     Red         AUTO
# 147  2000  Normal   5980    96841     Red         AUTO
# 148  2001  Normal   4899   151479  Yellow         AUTO
# 149  2000  Normal   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Reading Excel workbook

# %% [markdown]
# #### Reading excel workbook and csv is same but if in excel there are multiple sheets,
# #### then we can mention the sheet number or sheet name after giving the path
# #### Also here sep and delimeter is not used as excel sheet is already in tabular form

# %% [markdown]
# #### Below sheet_name=None means it displays all the data of every sheet

# %%
pd.read_excel("E:/Dataset/Data/fruits.xlsx",sheet_name=None)
# Out:
# {'fruits':               Color  Sphericity  Weight  labels
#  0            Orange       0.947     120  Orange
#  1            Orange       0.917     125  Orange
#  2            Orange       0.923     110  Orange
#  3            Orange       0.916     123  Orange
#  4            Orange       0.943     124  Orange
#  5            Orange       0.911     130  Orange
#  6            Orange       0.903     135  Orange
#  7            Orange       0.918     105  Orange
#  8            Orange       0.914     132  Orange
#  9            Orange       0.936     127  Orange
#  10  Greenish yellow       0.829     133  Orange
#  11  Greenish yellow       0.875     134  Orange
#  12  Greenish yellow       0.859     110  Orange
#  13            Green       0.849     119  Orange
#  14            Green       0.868     106  Orange
#  15  Greenish yellow       0.884     113  Orange
#  16  Greenish yellow       0.872     108  Orange
#  17  Greenish yellow       0.823     132  Orange
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ##### Reading only a single sheet, here the we can mention sheet name or either sheet number from 0,1,2

# %%
pd.read_excel("E:/Dataset/Data/fruits.xlsx",sheet_name=0)
# Out:
#               Color  Sphericity  Weight  labels
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange
# 16  Greenish yellow       0.872     108  Orange
# 17  Greenish yellow       0.823     132  Orange
# 18            Green       0.853     119  Orange
# ...

# %%
data = pd.read_excel("E:/Dataset/Data/fruits.xlsx",sheet_name=None)
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['fruits', 'cars', 'iris'])

# %%
data['iris'].head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
data['fruits'].head()
# Out:
#     Color  Sphericity  Weight  labels
# 0  Orange       0.947     120  Orange
# 1  Orange       0.917     125  Orange
# 2  Orange       0.923     110  Orange
# 3  Orange       0.916     123  Orange
# 4  Orange       0.943     124  Orange

# %%
data['cars'].head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO

# %%
data
# Out:
# {'fruits':               Color  Sphericity  Weight  labels
#  0            Orange       0.947     120  Orange
#  1            Orange       0.917     125  Orange
#  2            Orange       0.923     110  Orange
#  3            Orange       0.916     123  Orange
#  4            Orange       0.943     124  Orange
#  5            Orange       0.911     130  Orange
#  6            Orange       0.903     135  Orange
#  7            Orange       0.918     105  Orange
#  8            Orange       0.914     132  Orange
#  9            Orange       0.936     127  Orange
#  10  Greenish yellow       0.829     133  Orange
#  11  Greenish yellow       0.875     134  Orange
#  12  Greenish yellow       0.859     110  Orange
#  13            Green       0.849     119  Orange
#  14            Green       0.868     106  Orange
#  15  Greenish yellow       0.884     113  Orange
#  16  Greenish yellow       0.872     108  Orange
#  17  Greenish yellow       0.823     132  Orange
# ...

# %%
data.get('cars')
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]
